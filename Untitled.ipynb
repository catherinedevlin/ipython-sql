# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# !conda install -c conda-forge snowflake-sqlalchemy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/idomi/opt/miniconda3/envs/jupysql
#
#   added / updated specs:
#     - snowflake-sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-11.0.0           |  hce30654_13_cpu          31 KB  conda-forge
#     asn1crypto-1.5.1           |     pyhd8ed1ab_0          79 KB  conda-forge
#     aws-c-auth-0.6.26          |       h9ec8a34_1          80 KB  conda-forge
#     aws-c-cal-0.5.21           |       h134b2d6_2          29 KB  conda-forge
#     aws-c-common-0.8.14        |       h1a8c8d9_0         173 KB  conda-forge
#     aws-c-compression-0.2.16   |       h59b28b2_5          17 KB  conda-forge
#     aws-c-event-stream-0.2.20  |       ha370d96_4          46 KB  conda-forge
#     aws-c-http-0.7.6           |       hca61f3c_0         145 KB  conda-forge
#     aws-c-io-0.13.19           |       ha2443f3_3         121 KB  conda-forge
#     aws-c-mqtt-0.8.6           |      hcd3fa0e_12         100 KB  conda-forge
#     aws-c-s3-0.2.7             |       hc514de9_1          66 KB  conda-forge
#     aws-c-sdkutils-0.1.8       |       h59b28b2_0          46 KB  conda-forge
#     aws-checksums-0.1.14       |       h59b28b2_5          48 KB  conda-forge
#     aws-crt-cpp-0.19.8         |      h6be2766_12         210 KB  conda-forge
#     aws-sdk-cpp-1.10.57        |       h3daea3c_8         3.2 MB  conda-forge
#     brotlipy-0.7.0             |py310h8e9501a_1005         351 KB  conda-forge
#     cffi-1.15.1                |  py310h2399d43_3         214 KB  conda-forge
#     charset-normalizer-2.1.1   |     pyhd8ed1ab_0          36 KB  conda-forge
#     cryptography-38.0.4        |  py310hfc83b78_0         1.0 MB  conda-forge
#     filelock-3.10.7            |     pyhd8ed1ab_0          14 KB  conda-forge
#     gflags-2.2.2               |    hc88da5d_1004          85 KB  conda-forge
#     glog-0.6.0                 |       h6da1cb0_0          95 KB  conda-forge
#     greenlet-2.0.2             |  py310h0f1eb42_0         177 KB  conda-forge
#     idna-3.4                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     importlib-metadata-6.1.0   |     pyha770c72_0          24 KB  conda-forge
#     libabseil-20230125.0       | cxx17_hb7217d7_1         1.1 MB  conda-forge
#     libarrow-11.0.0            |  hdcd110a_13_cpu        16.3 MB  conda-forge
#     libcrc32c-1.1.2            |       hbdafb3b_0          18 KB  conda-forge
#     libcurl-7.88.1             |       h9049daf_1         315 KB  conda-forge
#     libcxx-16.0.0              |       h75e25f2_0         1.1 MB  conda-forge
#     libevent-2.1.10            |       h7673551_4         1.2 MB  conda-forge
#     libgfortran-5.0.0          |12_2_0_hd922786_31         157 KB  conda-forge
#     libgfortran5-12.2.0        |      h0eea778_31         1.0 MB  conda-forge
#     libgoogle-cloud-2.8.0      |       h7206bc8_1        25.2 MB  conda-forge
#     libgrpc-1.52.1             |       he98ff75_1         3.3 MB  conda-forge
#     libnghttp2-1.52.0          |       hae82a92_0         551 KB  conda-forge
#     libprotobuf-3.21.12        |       hb5ab8b9_0         1.7 MB  conda-forge
#     libthrift-0.18.1           |       h6635e49_0         305 KB  conda-forge
#     libutf8proc-2.8.0          |       h1a8c8d9_0         101 KB  conda-forge
#     llvm-openmp-16.0.0         |       h7cfbb63_0         264 KB  conda-forge
#     lz4-c-1.9.4                |       hb7217d7_0         138 KB  conda-forge
#     numpy-1.24.2               |  py310h3d2048e_0         5.3 MB  conda-forge
#     openssl-3.1.0              |       h03a7124_0         2.0 MB  conda-forge
#     orc-1.8.3                  |       hef0d403_0         354 KB  conda-forge
#     oscrypto-1.2.1             |     pyhd3deb0d_0         120 KB  conda-forge
#     parquet-cpp-1.5.1          |                2           3 KB  conda-forge
#     pyarrow-11.0.0             |py310h89f3c6b_13_cpu         3.4 MB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pycryptodomex-3.16.0       |  py310h8e9501a_0         1.3 MB  conda-forge
#     pyjwt-2.6.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_1         120 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     python-3.10.10             |h3ba56d0_0_cpython        11.0 MB  conda-forge
#     python_abi-3.10            |          3_cp310           6 KB  conda-forge
#     pytz-2023.3                |     pyhd8ed1ab_0         182 KB  conda-forge
#     re2-2023.02.02             |       hb7217d7_0         166 KB  conda-forge
#     requests-2.28.2            |     pyhd8ed1ab_1          56 KB  conda-forge
#     snappy-1.1.10              |       h17c5cce_0          33 KB  conda-forge
#     snowflake-connector-python-3.0.2|  py310h2798aea_0         672 KB  conda-forge
#     snowflake-sqlalchemy-1.4.7 |     pyhd8ed1ab_0          33 KB  conda-forge
#     sqlalchemy-1.4.46          |  py310h8e9501a_0         1.9 MB  conda-forge
#     typing_extensions-4.5.0    |     pyha770c72_0          31 KB  conda-forge
#     urllib3-1.26.15            |     pyhd8ed1ab_0         110 KB  conda-forge
#     zipp-3.15.0                |     pyhd8ed1ab_0          17 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        86.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   arrow-cpp          conda-forge/osx-arm64::arrow-cpp-11.0.0-hce30654_13_cpu
#   asn1crypto         conda-forge/noarch::asn1crypto-1.5.1-pyhd8ed1ab_0
#   aws-c-auth         conda-forge/osx-arm64::aws-c-auth-0.6.26-h9ec8a34_1
#   aws-c-cal          conda-forge/osx-arm64::aws-c-cal-0.5.21-h134b2d6_2
#   aws-c-common       conda-forge/osx-arm64::aws-c-common-0.8.14-h1a8c8d9_0
#   aws-c-compression  conda-forge/osx-arm64::aws-c-compression-0.2.16-h59b28b2_5
#   aws-c-event-stream conda-forge/osx-arm64::aws-c-event-stream-0.2.20-ha370d96_4
#   aws-c-http         conda-forge/osx-arm64::aws-c-http-0.7.6-hca61f3c_0
#   aws-c-io           conda-forge/osx-arm64::aws-c-io-0.13.19-ha2443f3_3
#   aws-c-mqtt         conda-forge/osx-arm64::aws-c-mqtt-0.8.6-hcd3fa0e_12
#   aws-c-s3           conda-forge/osx-arm64::aws-c-s3-0.2.7-hc514de9_1
#   aws-c-sdkutils     conda-forge/osx-arm64::aws-c-sdkutils-0.1.8-h59b28b2_0
#   aws-checksums      conda-forge/osx-arm64::aws-checksums-0.1.14-h59b28b2_5
#   aws-crt-cpp        conda-forge/osx-arm64::aws-crt-cpp-0.19.8-h6be2766_12
#   aws-sdk-cpp        conda-forge/osx-arm64::aws-sdk-cpp-1.10.57-h3daea3c_8
#   brotlipy           conda-forge/osx-arm64::brotlipy-0.7.0-py310h8e9501a_1005
#   c-ares             conda-forge/osx-arm64::c-ares-1.18.1-h3422bc3_0
#   cffi               conda-forge/osx-arm64::cffi-1.15.1-py310h2399d43_3
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.1.1-pyhd8ed1ab_0
#   cryptography       conda-forge/osx-arm64::cryptography-38.0.4-py310hfc83b78_0
#   filelock           conda-forge/noarch::filelock-3.10.7-pyhd8ed1ab_0
#   gflags             conda-forge/osx-arm64::gflags-2.2.2-hc88da5d_1004
#   glog               conda-forge/osx-arm64::glog-0.6.0-h6da1cb0_0
#   gmp                conda-forge/osx-arm64::gmp-6.2.1-h9f76cd9_0
#   greenlet           conda-forge/osx-arm64::greenlet-2.0.2-py310h0f1eb42_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1ab_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-6.1.0-pyha770c72_0
#   krb5               conda-forge/osx-arm64::krb5-1.20.1-h69eda48_0
#   libabseil          conda-forge/osx-arm64::libabseil-20230125.0-cxx17_hb7217d7_1
#   libarrow           conda-forge/osx-arm64::libarrow-11.0.0-hdcd110a_13_cpu
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-16_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.0.9-h1a8c8d9_8
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.0.9-h1a8c8d9_8
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.0.9-h1a8c8d9_8
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-16_osxarm64_openblas
#   libcrc32c          conda-forge/osx-arm64::libcrc32c-1.1.2-hbdafb3b_0
#   libcurl            conda-forge/osx-arm64::libcurl-7.88.1-h9049daf_1
#   libcxx             conda-forge/osx-arm64::libcxx-16.0.0-h75e25f2_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h642e427_1
#   libevent           conda-forge/osx-arm64::libevent-2.1.10-h7673551_4
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-12_2_0_hd922786_31
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-12.2.0-h0eea778_31
#   libgoogle-cloud    conda-forge/osx-arm64::libgoogle-cloud-2.8.0-h7206bc8_1
#   libgrpc            conda-forge/osx-arm64::libgrpc-1.52.1-he98ff75_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-16_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.52.0-hae82a92_0
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.21-openmp_hc731615_3
#   libprotobuf        conda-forge/osx-arm64::libprotobuf-3.21.12-hb5ab8b9_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.40.0-h76d750c_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.10.0-h7a5bd25_3
#   libthrift          conda-forge/osx-arm64::libthrift-0.18.1-h6635e49_0
#   libutf8proc        conda-forge/osx-arm64::libutf8proc-2.8.0-h1a8c8d9_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.2.13-h03a7124_4
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-16.0.0-h7cfbb63_0
#   lz4-c              conda-forge/osx-arm64::lz4-c-1.9.4-hb7217d7_0
#   numpy              conda-forge/osx-arm64::numpy-1.24.2-py310h3d2048e_0
#   orc                conda-forge/osx-arm64::orc-1.8.3-hef0d403_0
#   oscrypto           conda-forge/noarch::oscrypto-1.2.1-pyhd3deb0d_0
#   packaging          conda-forge/noarch::packaging-23.0-pyhd8ed1ab_0
#   parquet-cpp        conda-forge/noarch::parquet-cpp-1.5.1-2
#   pyarrow            conda-forge/osx-arm64::pyarrow-11.0.0-py310h89f3c6b_13_cpu
#   pycparser          conda-forge/noarch::pycparser-2.21-pyhd8ed1ab_0
#   pycryptodomex      conda-forge/osx-arm64::pycryptodomex-3.16.0-py310h8e9501a_0
#   pyjwt              conda-forge/noarch::pyjwt-2.6.0-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-22.0.0-pyhd8ed1ab_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python_abi         conda-forge/osx-arm64::python_abi-3.10-3_cp310
#   pytz               conda-forge/noarch::pytz-2023.3-pyhd8ed1ab_0
#   re2                conda-forge/osx-arm64::re2-2023.02.02-hb7217d7_0
#   requests           conda-forge/noarch::requests-2.28.2-pyhd8ed1ab_1
#   snappy             conda-forge/osx-arm64::snappy-1.1.10-h17c5cce_0
#   snowflake-connect~ conda-forge/osx-arm64::snowflake-connector-python-3.0.2-py310h2798aea_0
#   snowflake-sqlalch~ conda-forge/noarch::snowflake-sqlalchemy-1.4.7-pyhd8ed1ab_0
#   sqlalchemy         conda-forge/osx-arm64::sqlalchemy-1.4.46-py310h8e9501a_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.5.0-pyha770c72_0
#   urllib3            conda-forge/noarch::urllib3-1.26.15-pyhd8ed1ab_0
#   zipp               conda-forge/noarch::zipp-3.15.0-pyhd8ed1ab_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.2-hf913c23_6
#
# The following packages will be UPDATED:
#
#   openssl              pkgs/main::openssl-1.1.1t-h1a28f6b_0 --> conda-forge::openssl-3.1.0-h03a7124_0
#   zlib                    pkgs/main::zlib-1.2.13-h5a0b063_0 --> conda-forge::zlib-1.2.13-h03a7124_4
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h4653dfc_0
#   certifi            pkgs/main/osx-arm64::certifi-2022.12.~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   python               pkgs/main::python-3.10.10-hc0d8a6c_2 --> conda-forge::python-3.10.10-h3ba56d0_0_cpython
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
from sqlalchemy import create_engine
from snowflake.sqlalchemy import URL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 2
#       1 from sqlalchemy import create_engine
# ----> 2 from snowflake.sqlalchemy import URL
#
# ModuleNotFoundError: No module named 'snowflake'

# %%
engine = create_engine(URL(
    account = '<account>',
    user = '<user>',
    database = 'testdb',
    schema = 'public',
    warehouse = '<wh>',
    role='public',
    authenticator='externalbrowser'
))
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 3
#       1 get_ipython().run_line_magic('load_ext', 'sql')
#       2 from sqlalchemy import create_engine
# ----> 3 from snowflake.sqlalchemy import URL
#       5 engine = create_engine(URL(
#       6     account = '<account>',
#       7     user = '<user>',
#    (...)
#      12     authenticator='externalbrowser'
#      13 ))
#      14 connection = engine.connect()
#
# ModuleNotFoundError: No module named 'snowflake'
